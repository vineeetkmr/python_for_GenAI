# %%
import numpy as nm
import pandas as pd

# Addition
array1=nm.array([1,2,3,5,4])
array2 = nm.array([10,20,4,50,23])

result =array1+array2
print(result)
# Out:
# [11 22  7 55 27]

# %%
data=pd.read_csv("https://raw.githubusercontent.com/vineeetkmr/python_for_GenAI/refs/heads/master/HclTrainingPractice/Customer.csv")

print(data)
# Out:
#    CustomerID  Age  Gender  Income  Spending Score  Purchase Frequency  \
# 0        C001   28  Female   52000              78                  12
# 1        C002   35    Male   68000              65                   8
# 2        C003   42  Female   75000              82                  15
# 3        C004   23    Male   41000              55                   6
# 4        C005   31  Female   59000              73                  10
# ..        ...  ...     ...     ...             ...                 ...
# 95       C096   50  Female   93000              90                  17
# 96       C097   28    Male   56000              74                  11
# 97       C098   39  Female   73000              76                  12
# 98       C099   47    Male   87000              85                  15
# 99       C100   53  Female   96000              91                  18
#
#     Tenure  Location/City Membership Level Last Purchase Date  \
# ...
