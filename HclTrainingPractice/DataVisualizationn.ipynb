# %%
import numpy as np

# %%
#Vector addition
a=np.array([1,2,3])
b=np.array([4,5,6])
c=a+b
print(c)
# Out:
# [5 7 9]

# %%
#Vector Subtraction
print(a-b)
# Out:
# [-3 -3 -3]

# %%
#Vector Multiplication
print(a*b)
print(a*5)
# Out:
# [ 4 10 18]
# [ 5 10 15]

# %%
# Dot product
result=np.dot(a,b)
print(result)
# Out:
# 32
